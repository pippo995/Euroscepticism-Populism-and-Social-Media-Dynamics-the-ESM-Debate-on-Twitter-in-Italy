# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import re

pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

# %%
df = pd.read_csv('MES_DEFINITIVO.csv', low_memory=False)
df
# Out:
#                     author      aut_scrname             tweet_id  \
# 0       ROBYUS              78_robyus        1198961837112475653
# 1       ROBYUS              78_robyus        1200291943944740866
# 2       Antonia Agostini    antoniacri       1198962278047068162
# 3       Antonia Agostini    antoniacri       1199406183779618816
# 4       Antonia Agostini    antoniacri       1199487003877924865
# ...                   ...          ...                       ...
# 241495  Matteo Corrocher    CorrocherMatteo  1206344347345702917
# 241496  Giancarlo Poli      GiancarloPoli7   1206350546069794816
# 241497  Dni b               dnl_brg          1206353837805707264
# 241498  Stefano Capaccioli  s_capaccioli     1206360068679188481
# 241499  Fiore Liborio       FioreLiborio     1206361569661243393
#
#                                                                                                                                                                                                                                                                                                                  retweeted_status  \
# 0       La riforma del #Mes e una cagata pazzesca! \nhttps://t.co/Z9w4KlUVcb https://t.co/ddSx5mx4Ou
# 1       A prescindere dal Vostro orientamento politico @GiorgiaMeloni ha dato voce a TUTTI\n\n#Meloni \n#StopMes\n#MES\n#Conte https://t.co/6Dmvg4C4IN
# 2       Giorno 9\n#StopMes  NO al #MES\n#StopMes No al #MES \n#StopMes  NO al #MES \n#StopMes  NO al #MES\n#StopMes  NO al #MES \n#StopMes  NO al #MES
# 3       Bisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES
# 4       giorno 10\nAnche oggi\n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes
# ...                                                                                                                                                                                                                                       ...
# 241495  Quando un cialtrone sovranista dice che il #MES serve per salvare  Deutsche Bank con i soldi italiani, ricordagli questa lista di banche nostrane e chiedigli quanto quota il CDS di DB rispetto alla piu grande banca italiana. Se ti risponde Bacioni, hai trovato il Capitano. https://t.co/zGoQRr4s6w
# 241496  La#bancapopolareBaristava per saltare in aria nel silenzio del governo:oltre 3000 dipendenti e 300 sportelli coinvolti. Alla banca era stato negato dall'UE l'aiuto del fondo interbancario nel 2014 per salvare banca Tercas: ed ecco i risultati!E adesso ci chiedono pure il#MES?! https://t.co/ZXyuIwa1gk
# 241497  NaN
# 241498  Un altra settimana e trascorsa e Deutsche Bank non e fallita.\nInvece abbiamo: \n-Banca Popolare Vicenza\n-Veneto Banca\n-Banca Marche\n-Banca Etruria \n-Tercas\n-Carife\n-Cr San Miniato\n-Carichieti\n-Cari Cesena\n-Carim\n-Carige\n-Banca Popolare Bari\n\nTutta colpa del #Mes e dell'#Euro https://t.co/0t4D4SSs3v
# 241499  Un altro cambio di casacca? \n#Grassi #Lucidi #Urraro #Mes #DiMaio https://t.co/ifP6FXUjeg
#
#                                                                                                                                                                                                               full_text  \
# 0       RT @Rinaldi_euro: La riforma del #Mes e una cagata pazzesca! \nhttps://t.co/Z9w4KlUVcb https://t.co/ddSx5mx4Ou
# 1       RT @flayawa: A prescindere dal Vostro orientamento politico @GiorgiaMeloni ha dato voce a TUTTI\n\n#Meloni \n#StopMes\n#MES\n#Conte https://t.co
# 2       RT @Nadezhda24Kr: Giorno 9\n#StopMes  NO al #MES\n#StopMes No al #MES \n#StopMes  NO al #MES \n#StopMes  NO al #MES\n#StopMes  NO al #MES \n#Stop
# 3       RT @Nadezhda24Kr: Bisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #MES\nBisogna bloccare il #
# 4       RT @VedeleAngela: giorno 10\nAnche oggi\n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #MES \n#StopMes No al #
# ...                                                                                                                                                   ...
# 241495  RT @carloalberto: Quando un cialtrone sovranista dice che il #MES serve per salvare  Deutsche Bank con i soldi italiani, ricordagli questa
# 241496  RT @EmanueleSavass1: La#bancapopolareBaristava per saltare in aria nel silenzio del governo:oltre 3000 dipendenti e 300 sportelli coinvol
# 241497  Idee utili per restare europei\n.\n.\n.\nBreve estratto tenuto dalla docente Veronica De Romanis al #moreimpresa #europa #ue #unioneeuropea #mes #veronicaderomanis #modena @ Accademia https://t.co/Ic9iJ2ZA29
# 241498  RT @antonioripa: Un altra settimana e trascorsa e Deutsche Bank non e fallita.\nInvece abbiamo: \n-Banca Popolare Vicenza\n-Veneto Banca\n-Banc
# 241499  RT @lefrasidiosho: Un altro cambio di casacca? \n#Grassi #Lucidi #Urraro #Mes #DiMaio https://t.co/ifP6FXUjeg
#
#        reply           created_at  retweet_count  favorite_count hashtags  \
# 0       NaN   2019-11-25 13:49:12  612            0               None
# 1       NaN   2019-11-29 05:54:34  151            0               None
# 2       NaN   2019-11-25 13:50:57  1              0               None
# 3       NaN   2019-11-26 19:14:52  2              0               None
# 4       NaN   2019-11-27 00:36:01  18             0               None
# ...     ...                   ...  ..            ..                ...
# 241495  NaN   2019-12-15 22:44:39  172            0               None
# 241496  NaN   2019-12-15 23:09:17  53             0               None
# 241497  NaN   2019-12-15 23:22:22  0              0               None
# 241498  NaN   2019-12-15 23:47:08  193            0               NaN
# 241499  NaN   2019-12-15 23:53:05  194            0               None
#
#         ...  \
# 0       ...
# 1       ...
# 2       ...
# 3       ...
# 4       ...
# ...     ...
# 241495  ...
# 241496  ...
# 241497  ...
# 241498  ...
# 241499  ...
#
#                                                                                                                                                                                                                                                                              complete_text  \
# 0       La riforma del Mes e una cagata pazzesca
# 1       A prescindere dal Vostro orientamento politico GiorgiaMeloni ha dato voce a TUTTI Meloni StopMes MES Conte
# 2       Giorno 9 StopMes NO al MES StopMes No al MES StopMes NO al MES StopMes NO al MES StopMes NO al MES StopMes NO al MES
# 3       Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES Bisogna bloccare il MES
# 4       giorno 10 Anche oggi StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes No al MES StopMes
# ...                                                                                                                                                                                                ...
# 241495  Quando un cialtrone sovranista dice che il MES serve per salvare Deutsche Bank con i soldi italiani ricordagli questa lista di banche nostrane e chiedigli quanto quota il CDS di DB rispetto alla piu grande banca italiana Se ti risponde Bacioni hai trovato il Capitano
# 241496  La bancapopolareBaristava per saltare in aria nel silenzio del governo oltre 3000 dipendenti e 300 sportelli coinvolti Alla banca era stato negato dall UE l aiuto del fondo interbancario nel 2014 per salvare banca Tercas ed ecco i risultati E adesso ci chiedono pure il MES
# 241497  Idee utili per restare europei Breve estratto tenuto dalla docente Veronica De Romanis al moreimpresa europa ue unioneeuropea mes veronicaderomanis modena Accademia
# 241498  Un altra settimana e trascorsa e Deutsche Bank non e fallita Invece abbiamo Banca Popolare Vicenza Veneto Banca Banca Marche Banca Etruria Tercas Carife Cr San Miniato Carichieti Cari Cesena Carim Carige Banca Popolare Bari Tutta colpa del Mes e dell Euro
# 241499  Un altro cambio di casacca Grassi Lucidi Urraro Mes DiMaio
#
#        prev         p                0       cap universal    friend  \
# 0       1    1.000000  78_robyus        0.010165  0.170132  0.311763
# 1       1    0.971212  78_robyus        0.010165  0.170132  0.311763
# 2       1    0.976877  antoniacri       0.005213  0.111167  0.178233
# 3       1    0.993002  antoniacri       0.005213  0.111167  0.178233
# 4       1    0.976976  antoniacri       0.005213  0.111167  0.178233
# ...    ..         ...         ...            ...       ...       ...
# 241495  3    1.000000  CorrocherMatteo -1.000000 NaN       NaN
# 241496  1    1.000000  GiancarloPoli7   0.002198  0.044479  0.094077
# 241497  1    0.992041  dnl_brg         -1.000000 NaN       NaN
# 241498  3    1.000000  s_capaccioli     0.002910  0.065656  0.150687
# 241499  2    1.000000  FioreLiborio     0.002198  0.044479  0.188251
#
#         temporal      user   network
# 0       0.460315  0.067460  0.129106
# 1       0.460315  0.067460  0.129106
# 2       0.301336  0.212079  0.568829
# 3       0.301336  0.212079  0.568829
# 4       0.301336  0.212079  0.568829
# ...          ...       ...       ...
# 241495 NaN       NaN       NaN
# 241496  0.105017  0.032318  0.063076
# 241497 NaN       NaN       NaN
# 241498  0.208029  0.050425  0.109970
# 241499  0.275895  0.050425  0.246102
#
# [241500 rows x 36 columns]

# %%
df['retweet_count'].value_counts().head(10)
# Out:
# 0       16068
# 1       7133
# 2       4993
# 3       3799
# 1951    3661
# 4       3146
# 5       2892
# 6       2465
# 8       2194
# 7       2128
# Name: retweet_count, dtype: int64
